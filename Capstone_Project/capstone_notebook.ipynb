# %% [markdown]
# # Capstone Project: Comprehensive AI Agent
#
# This notebook demonstrates the Capstone AI Agent that integrates:
# - **Tool Use** (Day 2)
# - **Memory Management** (Day 3)
# - **Observability** (Day 4)

# %%
# !pip install google-generativeai

# %%
import os
import json
from capstone_agent import CapstoneAgent

os.environ["GOOGLE_API_KEY"] = "your-api-key-here"

# %% [markdown]
# ## Initialize Agent

# %%
agent = CapstoneAgent(user_id="notebook_user")
print("✓ Agent initialized")

# %% [markdown]
# ## Example: Tool Use, Memory, Observability

# %%
# Test all features
agent.chat("Calculate 10 * 5")
agent.chat("I like Python")
result = agent.chat("What do I like?")
print(result)

report = agent.get_observability_report()
print(json.dumps(report, indent=2))
